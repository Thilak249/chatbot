# %% [markdown]
# <a href="https://colab.research.google.com/github/Thilak249/chatbot/blob/main/simple_pyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
model = nn.Sequential(
    nn.Linear(2, 4),
    nn.ReLU(),
    nn.Linear(4, 1)
)

# %%
X = torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y = torch.tensor([[0.],[1.],[1.],[0.]])

# %% [markdown]
# loss function and optimizer
# . MSEloss measures prediction error
# . ADAM optimizer updates weights efficently

# %%
loss_fn = nn.MSELoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
for _ in range(1000):
  opt.zero_grad()
  loss = loss_fn(model(X), y)
  loss.backward()
  opt.step()

# %% [markdown]
# we print model prediction after training

# %%
print(model(X))
